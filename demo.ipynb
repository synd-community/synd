# %%
from syndkit.datasets.obesity import ObesityDataset
from syndkit.generators.strawman import StrawmanGenerator

dataset = ObesityDataset()
dataset.data
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 0     Female  21.000000  1.620000   64.000000                            yes
# 1     Female  21.000000  1.520000   56.000000                            yes
# 2       Male  23.000000  1.800000   77.000000                            yes
# 3       Male  27.000000  1.800000   87.000000                             no
# 4       Male  22.000000  1.780000   89.800000                             no
# ...      ...        ...       ...         ...                            ...
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
# ...

# %%
sg = StrawmanGenerator.train(dataset.data)

# %%
sg.generate(5)
# Out:
#      Gender        Age    Height      Weight family_history_with_overweight  \
# 1586   Male  25.509034  1.772190  114.097656                            yes
# 1711   Male  28.986237  1.758618  113.501549                            yes
# 419    Male  29.000000  1.620000   89.000000                            yes
# 328    Male  19.000000  1.740000   74.000000                            yes
# 1658   Male  30.424369  1.699354  100.176866                            yes
#
#      FAVC      FCVC      NCP       CAEC SMOKE      CH2O SCC       FAF  \
# 1586  yes  2.193310  3.00000  Sometimes    no  2.089983  no  1.360994
# 1711  yes  2.320201  3.00000  Sometimes    no  2.164784  no  0.000000
# 419   yes  1.000000  3.00000  Sometimes    no  1.000000  no  0.000000
# 328    no  3.000000  1.00000  Sometimes    no  3.000000  no  3.000000
# 1658  yes  2.819934  1.91863  Sometimes    no  1.000000  no  1.393020
#
#            TUE       CALC                 MTRANS    Obesity_level
# ...

# %%
from syndkit.generators.gaussian import GaussianMultivariateGenerator

gm = GaussianMultivariateGenerator.train(dataset.data)

# %%
gm.generate(5)
# Out:
#         Age    Height    Weight      FCVC       NCP      CH2O       FAF  \
# 0 -0.229340 -0.890436 -1.352792 -0.820124  1.142740 -1.592660 -0.606229
# 1  0.214176  1.007672 -0.195376  0.112272  1.609629 -1.401770 -0.497109
# 2  1.064548  0.444557  2.076366  0.950564  0.143150 -0.021327 -1.737637
# 3 -1.146877  0.239160 -1.480340 -1.564227 -0.227101 -0.054115 -0.103627
# 4  0.143088 -0.250352 -0.300248  1.596663 -1.536691 -0.987920  0.264320
#
#         TUE   Gender0   Gender1  ...   MTRANS2   MTRANS3   MTRANS4  \
# 0  0.476174 -0.502206  0.502894  ... -0.004457  0.306817 -0.126240
# 1 -1.056989  0.641186 -0.641940  ...  0.136437 -1.896474  0.034716
# 2 -0.527633  0.767762 -0.767633  ...  0.069269  0.482248 -0.256988
# 3  0.588050 -1.149675  1.149862  ...  0.044333  0.876262 -0.074572
# 4  1.699409  1.264699 -1.264646  ... -0.100268  0.758020 -0.362698
#
#    Obesity_level0  Obesity_level1  Obesity_level2  Obesity_level3  \
# ...
